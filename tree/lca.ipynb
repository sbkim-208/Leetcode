# %% [markdown]
# 일반 트리 → 어디있는지 모름
# 양쪽 다 탐색!
#
# dfs 올려보내는 값 = 정답
#
#
# ## time complexity
#    - O(n)
#    - 모든 노드 방문
#    - 재귀 스택 n개

# %%
class Solution: 

    def lowest_common_ancestor(self, root, p,q):

        def dfs(root):

            if not root: 
                return 
            
            if root == p or root == q:
                return root
            
            left = dfs(root.left)
            right = dfs(root.right)

            if left and right: 
                return root
            
            return left or right
            

            


        return dfs(root)
