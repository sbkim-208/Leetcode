# %%
# 공간 요구 
class Node:
    def __init__(self, val = 0, next = None):
        self.val = val
        self.next = next


class Solution:
    def linked_list_cycle(self, head):


        visited = set()

        curr = head

        while curr:

            if curr not in visited:
                visited.add(curr)

                curr = curr.next

            
            
            else:
                return True
            
        
        return False # 다돌았는데 없다 -> return False

# %%
class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:

        slow = head
        fast = head


        while fast and fast.next :

            slow = slow.next
            fast = fast.next.next

            if slow == fast:
                return True
        return False

# %%
# Time

## O(n)

"""

Floyd's Cycle-Finding Algorithm

slow and fast 가 있음
공간 복잡도에서 큰 차이가 남
-> 다른 방법은 새로운 공간을 요구함


"""
