# %%
from typing import List
from collections import deque

class Solution:
    def orangesRotting(self, grid: List[List[int]]) -> int:

        queue = deque()


        row = len(grid)
        col = len(grid[0])


# 썩은 오렌지 찾기
        for i in range(row): 
            for j in range(col): 
                if grid[i][j] == 2: 

                    queue.append((i,j))
        
        count = 0

        while queue : 
            count +=1

            for _ in range(len(queue)): 

                ni,nx = queue.popleft()

                if (ni + 1) >  0 and  (ni + 1 ) < row and (nx +1) > 0 and (nx+1) < col: 

                    if queue[ni+1][nx] == 1: 
                        queue.append((ni+1, nx))
                    if queue[ni-1][nx] == 1: 
                        queue.a

# %%
from typing import List
from collections import deque

class Solution:
    def orangesRotting(self, grid: List[List[int]]) -> int:

        queue = deque()


        row = len(grid)
        col = len(grid[0])


# 썩은 오렌지 찾기
