# %%
class Solution:

    def lcs(self,nums):

        hash = set(nums)
        max_length = 0


        for num in nums:
            if num -1 not in hash:

                length = 1

                while length + num in hash :

                    legth +=1
                max_length = max(length, max_length)






        return max_length
